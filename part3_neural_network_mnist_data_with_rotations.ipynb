# %%
# python notebook for Make Your Own Neural Network
# code for a 3-layer neural network, and code for learning the MNIST dataset
# this version creates additional training examples by rotating each original by +/- 10 degrees
# xytywh, 2019/06/19

# %%
# numpy provides arrays and useful functions for working with them
import numpy
# scipy.special for the sigmoid function expit()
import scipy.special
# scipy.ndimage for rotating image arrays
import scipy.ndimage

# %%
# neural network class definition
class neuralNetwork:
    # initialise the neural network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        # set number of nodes in each input, hidden, output layer
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes

        # link weight matrices, wih and who
        # weights inside the arrays are w_i_j, where link is from node i to node j in the next layer
        # w11 w21
        # w12 w22 etc 
        self.wih = numpy.random.normal(0.0, pow(self.inodes, -0.5), (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.onodes, self.hnodes))

        # learning rate
        self.lr = learningrate

        # activation function is the sigmoid function
        self.activation_function = lambda x: scipy.special.expit(x)

        pass

    # train the neural network
    def train(self, inputs_list, targets_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        targets = numpy.array(targets_list, ndmin=2).T

        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)

        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)

        # output layer error is the (target - actual)
        output_errors = targets - final_outputs
        # hidden layer error is the output_errors, split by weights, recombined at hidden nodes
        hidden_errors = numpy.dot(self.who.T, output_errors)

        # update the weights for the links between the hidden and output layers
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)),
                                        numpy.transpose(hidden_outputs))

        # update the weights for the links between the input and hidden layers
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)),
                                        numpy.transpose(inputs))

        pass

    # query the neural network
    def query(self, inputs_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T

        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)

        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)

        return final_outputs

# %%
# number of input, hidden and output nodes
input_nodes = 784
hidden_nodes = 200
output_nodes = 10

# learning rate
learning_rate = 0.01

# create instance of neural network
n = neuralNetwork(input_nodes,hidden_nodes,output_nodes, learning_rate)

# %%
# load the mnist training data CSV file into a list
training_data_file = open("mnist_dataset/mnist_train_60000.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

# %%
# train the neural network

# epochs is the number of times the training data set is used for training
epochs = 10

for e in range(epochs):
    # go through all records in the training data set
    print("Starting epoch-{}".format(e+1))
    i = 0
    for record in training_data_list:
        # split the record by the ',' commas
        all_values = record.split(',')
        # scale and shift the inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        i += 1
        print("Iteration-{} the shape of inputs is:{}".format(i,inputs.shape))
        # create the target output values (all 0.01, except the desired label which is 0.99)
        targets = numpy.zeros(output_nodes) + 0.01
        # all_values[0] is the target label for this record
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)

        ## create rotated variations
        # rotated anticlockwise by x degrees
        # 图像逆时针旋转10度
        inputs_plusx_img = scipy.ndimage.interpolation.rotate(inputs.reshape(28, 28), 10, cval=0.01, order=1,
                                                              reshape=False)
        n.train(inputs_plusx_img.reshape(784), targets)
        # rotated clockwise by x degrees
        # 图像顺时针旋转10度
        inputs_minusx_img = scipy.ndimage.interpolation.rotate(inputs.reshape(28, 28), -10, cval=0.01, order=1,
                                                               reshape=False)
        n.train(inputs_minusx_img.reshape(784), targets)


    print("Epoch-{} is finished\n".format(e+1))
# Out:
# Starting epoch-1
# Iteration-1 the shape of inputs is:(784,)
# Iteration-2 the shape of inputs is:(784,)
# Iteration-3 the shape of inputs is:(784,)
# Iteration-4 the shape of inputs is:(784,)
# Iteration-5 the shape of inputs is:(784,)
# Iteration-6 the shape of inputs is:(784,)
# Iteration-7 the shape of inputs is:(784,)
# Iteration-8 the shape of inputs is:(784,)
# Iteration-9 the shape of inputs is:(784,)
# Iteration-10 the shape of inputs is:(784,)
# Iteration-11 the shape of inputs is:(784,)
# Iteration-12 the shape of inputs is:(784,)
# Iteration-13 the shape of inputs is:(784,)
# Iteration-14 the shape of inputs is:(784,)
# Iteration-15 the shape of inputs is:(784,)
# Iteration-16 the shape of inputs is:(784,)
# Iteration-17 the shape of inputs is:(784,)
# Iteration-18 the shape of inputs is:(784,)
# Iteration-19 the shape of inputs is:(784,)
# Iteration-20 the shape of inputs is:(784,)
# Iteration-21 the shape of inputs is:(784,)
# Iteration-22 the shape of inputs is:(784,)
# Iteration-23 the shape of inputs is:(784,)
# Iteration-24 the shape of inputs is:(784,)
# Iteration-25 the shape of inputs is:(784,)
# Iteration-26 the shape of inputs is:(784,)
# Iteration-27 the shape of inputs is:(784,)
# Iteration-28 the shape of inputs is:(784,)
# Iteration-29 the shape of inputs is:(784,)
# Iteration-30 the shape of inputs is:(784,)
# Iteration-31 the shape of inputs is:(784,)
# Iteration-32 the shape of inputs is:(784,)
# Iteration-33 the shape of inputs is:(784,)
# Iteration-34 the shape of inputs is:(784,)
# Iteration-35 the shape of inputs is:(784,)
# Iteration-36 the shape of inputs is:(784,)
# Iteration-37 the shape of inputs is:(784,)
# Iteration-38 the shape of inputs is:(784,)
# Iteration-39 the shape of inputs is:(784,)
# Iteration-40 the shape of inputs is:(784,)
# Iteration-41 the shape of inputs is:(784,)
# Iteration-42 the shape of inputs is:(784,)
# Iteration-43 the shape of inputs is:(784,)
# Iteration-44 the shape of inputs is:(784,)
# Iteration-45 the shape of inputs is:(784,)
# Iteration-46 the shape of inputs is:(784,)
# Iteration-47 the shape of inputs is:(784,)
# Iteration-48 the shape of inputs is:(784,)
# Iteration-49 the shape of inputs is:(784,)
# Iteration-50 the shape of inputs is:(784,)
# Iteration-51 the shape of inputs is:(784,)
# Iteration-52 the shape of inputs is:(784,)
# Iteration-53 the shape of inputs is:(784,)
# Iteration-54 the shape of inputs is:(784,)
# Iteration-55 the shape of inputs is:(784,)
# Iteration-56 the shape of inputs is:(784,)
# Iteration-57 the shape of inputs is:(784,)
# Iteration-58 the shape of inputs is:(784,)
# Iteration-59 the shape of inputs is:(784,)
# Iteration-60 the shape of inputs is:(784,)
# Iteration-61 the shape of inputs is:(784,)
# Iteration-62 the shape of inputs is:(784,)
# Iteration-63 the shape of inputs is:(784,)
# Iteration-64 the shape of inputs is:(784,)
# Iteration-65 the shape of inputs is:(784,)
# Iteration-66 the shape of inputs is:(784,)
# Iteration-67 the shape of inputs is:(784,)
# Iteration-68 the shape of inputs is:(784,)
# Iteration-69 the shape of inputs is:(784,)
# Iteration-70 the shape of inputs is:(784,)
# Iteration-71 the shape of inputs is:(784,)
# Iteration-72 the shape of inputs is:(784,)
# Iteration-73 the shape of inputs is:(784,)
# Iteration-74 the shape of inputs is:(784,)
# Iteration-75 the shape of inputs is:(784,)
# Iteration-76 the shape of inputs is:(784,)
# Iteration-77 the shape of inputs is:(784,)
# Iteration-78 the shape of inputs is:(784,)
# Iteration-79 the shape of inputs is:(784,)
# Iteration-80 the shape of inputs is:(784,)
# Iteration-81 the shape of inputs is:(784,)
# Iteration-82 the shape of inputs is:(784,)
# Iteration-83 the shape of inputs is:(784,)
# Iteration-84 the shape of inputs is:(784,)
# Iteration-85 the shape of inputs is:(784,)
# Iteration-86 the shape of inputs is:(784,)
# Iteration-87 the shape of inputs is:(784,)
# Iteration-88 the shape of inputs is:(784,)
# Iteration-89 the shape of inputs is:(784,)
# Iteration-90 the shape of inputs is:(784,)
# Iteration-91 the shape of inputs is:(784,)
# Iteration-92 the shape of inputs is:(784,)
# Iteration-93 the shape of inputs is:(784,)
# Iteration-94 the shape of inputs is:(784,)
# Iteration-95 the shape of inputs is:(784,)
# Iteration-96 the shape of inputs is:(784,)
# Iteration-97 the shape of inputs is:(784,)
# Iteration-98 the shape of inputs is:(784,)
# Iteration-99 the shape of inputs is:(784,)
# Iteration-100 the shape of inputs is:(784,)
# Iteration-101 the shape of inputs is:(784,)
# Iteration-102 the shape of inputs is:(784,)
# Iteration-103 the shape of inputs is:(784,)
# Iteration-104 the shape of inputs is:(784,)
# Iteration-105 the shape of inputs is:(784,)
# Iteration-106 the shape of inputs is:(784,)
# Iteration-107 the shape of inputs is:(784,)
# Iteration-108 the shape of inputs is:(784,)
# Iteration-109 the shape of inputs is:(784,)
# Iteration-110 the shape of inputs is:(784,)
# Iteration-111 the shape of inputs is:(784,)
# Iteration-112 the shape of inputs is:(784,)
# Iteration-113 the shape of inputs is:(784,)
# Iteration-114 the shape of inputs is:(784,)
# Iteration-115 the shape of inputs is:(784,)
# Iteration-116 the shape of inputs is:(784,)
# Iteration-117 the shape of inputs is:(784,)
# Iteration-118 the shape of inputs is:(784,)
# Iteration-119 the shape of inputs is:(784,)
# Iteration-120 the shape of inputs is:(784,)
# Iteration-121 the shape of inputs is:(784,)
# Iteration-122 the shape of inputs is:(784,)
# Iteration-123 the shape of inputs is:(784,)
# Iteration-124 the shape of inputs is:(784,)
# Iteration-125 the shape of inputs is:(784,)
# Iteration-126 the shape of inputs is:(784,)
# Iteration-127 the shape of inputs is:(784,)
# Iteration-128 the shape of inputs is:(784,)
# Iteration-129 the shape of inputs is:(784,)
# Iteration-130 the shape of inputs is:(784,)
# Iteration-131 the shape of inputs is:(784,)
# Iteration-132 the shape of inputs is:(784,)
# Iteration-133 the shape of inputs is:(784,)
# Iteration-134 the shape of inputs is:(784,)
# Iteration-135 the shape of inputs is:(784,)
# Iteration-136 the shape of inputs is:(784,)
# Iteration-137 the shape of inputs is:(784,)
# Iteration-138 the shape of inputs is:(784,)
# Iteration-139 the shape of inputs is:(784,)
# Iteration-140 the shape of inputs is:(784,)
# Iteration-141 the shape of inputs is:(784,)
# Iteration-142 the shape of inputs is:(784,)
# Iteration-143 the shape of inputs is:(784,)
# Iteration-144 the shape of inputs is:(784,)
# Iteration-145 the shape of inputs is:(784,)
# Iteration-146 the shape of inputs is:(784,)
# Iteration-147 the shape of inputs is:(784,)
# Iteration-148 the shape of inputs is:(784,)
# Iteration-149 the shape of inputs is:(784,)
# Iteration-150 the shape of inputs is:(784,)
# Iteration-151 the shape of inputs is:(784,)
# Iteration-152 the shape of inputs is:(784,)
# Iteration-153 the shape of inputs is:(784,)
# Iteration-154 the shape of inputs is:(784,)
# Iteration-155 the shape of inputs is:(784,)
# Iteration-156 the shape of inputs is:(784,)
# Iteration-157 the shape of inputs is:(784,)
# Iteration-158 the shape of inputs is:(784,)
# Iteration-159 the shape of inputs is:(784,)
# Iteration-160 the shape of inputs is:(784,)
# Iteration-161 the shape of inputs is:(784,)
# Iteration-162 the shape of inputs is:(784,)
# Iteration-163 the shape of inputs is:(784,)
# Iteration-164 the shape of inputs is:(784,)
# Iteration-165 the shape of inputs is:(784,)
# Iteration-166 the shape of inputs is:(784,)
# Iteration-167 the shape of inputs is:(784,)
# Iteration-168 the shape of inputs is:(784,)
# Iteration-169 the shape of inputs is:(784,)
# Iteration-170 the shape of inputs is:(784,)
# Iteration-171 the shape of inputs is:(784,)
# Iteration-172 the shape of inputs is:(784,)
# Iteration-173 the shape of inputs is:(784,)
# Iteration-174 the shape of inputs is:(784,)
# Iteration-175 the shape of inputs is:(784,)
# Iteration-176 the shape of inputs is:(784,)
# Iteration-177 the shape of inputs is:(784,)
# Iteration-178 the shape of inputs is:(784,)
# Iteration-179 the shape of inputs is:(784,)
# Iteration-180 the shape of inputs is:(784,)
# Iteration-181 the shape of inputs is:(784,)
# Iteration-182 the shape of inputs is:(784,)
# Iteration-183 the shape of inputs is:(784,)
# Iteration-184 the shape of inputs is:(784,)
# Iteration-185 the shape of inputs is:(784,)
# Iteration-186 the shape of inputs is:(784,)
# Iteration-187 the shape of inputs is:(784,)
# Iteration-188 the shape of inputs is:(784,)
# Iteration-189 the shape of inputs is:(784,)
# Iteration-190 the shape of inputs is:(784,)
# Iteration-191 the shape of inputs is:(784,)
# Iteration-192 the shape of inputs is:(784,)
# Iteration-193 the shape of inputs is:(784,)
# Iteration-194 the shape of inputs is:(784,)
# Iteration-195 the shape of inputs is:(784,)
# Iteration-196 the shape of inputs is:(784,)
# Iteration-197 the shape of inputs is:(784,)
# Iteration-198 the shape of inputs is:(784,)
# Iteration-199 the shape of inputs is:(784,)
# Iteration-200 the shape of inputs is:(784,)
# Iteration-201 the shape of inputs is:(784,)
# Iteration-202 the shape of inputs is:(784,)
# Iteration-203 the shape of inputs is:(784,)
# Iteration-204 the shape of inputs is:(784,)
# Iteration-205 the shape of inputs is:(784,)
# Iteration-206 the shape of inputs is:(784,)
# Iteration-207 the shape of inputs is:(784,)
# Iteration-208 the shape of inputs is:(784,)
# Iteration-209 the shape of inputs is:(784,)
# Iteration-210 the shape of inputs is:(784,)
# Iteration-211 the shape of inputs is:(784,)
# Iteration-212 the shape of inputs is:(784,)
# Iteration-213 the shape of inputs is:(784,)
# Iteration-214 the shape of inputs is:(784,)
# Iteration-215 the shape of inputs is:(784,)
# Iteration-216 the shape of inputs is:(784,)
# Iteration-217 the shape of inputs is:(784,)
# Iteration-218 the shape of inputs is:(784,)
# Iteration-219 the shape of inputs is:(784,)
# Iteration-220 the shape of inputs is:(784,)
# Iteration-221 the shape of inputs is:(784,)
# Iteration-222 the shape of inputs is:(784,)
# Iteration-223 the shape of inputs is:(784,)
# Iteration-224 the shape of inputs is:(784,)
# Iteration-225 the shape of inputs is:(784,)
# Iteration-226 the shape of inputs is:(784,)
# Iteration-227 the shape of inputs is:(784,)
# Iteration-228 the shape of inputs is:(784,)
# Iteration-229 the shape of inputs is:(784,)
# Iteration-230 the shape of inputs is:(784,)
# Iteration-231 the shape of inputs is:(784,)
# Iteration-232 the shape of inputs is:(784,)
# Iteration-233 the shape of inputs is:(784,)
# Iteration-234 the shape of inputs is:(784,)
# Iteration-235 the shape of inputs is:(784,)
# Iteration-236 the shape of inputs is:(784,)
# Iteration-237 the shape of inputs is:(784,)
# Iteration-238 the shape of inputs is:(784,)
# Iteration-239 the shape of inputs is:(784,)
# Iteration-240 the shape of inputs is:(784,)
# Iteration-241 the shape of inputs is:(784,)
# Iteration-242 the shape of inputs is:(784,)
# Iteration-243 the shape of inputs is:(784,)
# Iteration-244 the shape of inputs is:(784,)
# Iteration-245 the shape of inputs is:(784,)
# Iteration-246 the shape of inputs is:(784,)
# Iteration-247 the shape of inputs is:(784,)
# Iteration-248 the shape of inputs is:(784,)
# Iteration-249 the shape of inputs is:(784,)
# Iteration-250 the shape of inputs is:(784,)
# Iteration-251 the shape of inputs is:(784,)
# Iteration-252 the shape of inputs is:(784,)
# Iteration-253 the shape of inputs is:(784,)
# Iteration-254 the shape of inputs is:(784,)
# Iteration-255 the shape of inputs is:(784,)
# Iteration-256 the shape of inputs is:(784,)
# Iteration-257 the shape of inputs is:(784,)
# Iteration-258 the shape of inputs is:(784,)
# Iteration-259 the shape of inputs is:(784,)
# Iteration-260 the shape of inputs is:(784,)
# Iteration-261 the shape of inputs is:(784,)
# Iteration-262 the shape of inputs is:(784,)
# Iteration-263 the shape of inputs is:(784,)
# Iteration-264 the shape of inputs is:(784,)
# Iteration-265 the shape of inputs is:(784,)
# Iteration-266 the shape of inputs is:(784,)
# Iteration-267 the shape of inputs is:(784,)
# Iteration-268 the shape of inputs is:(784,)
# Iteration-269 the shape of inputs is:(784,)
# Iteration-270 the shape of inputs is:(784,)
# Iteration-271 the shape of inputs is:(784,)
# Iteration-272 the shape of inputs is:(784,)
# Iteration-273 the shape of inputs is:(784,)
# Iteration-274 the shape of inputs is:(784,)
# Iteration-275 the shape of inputs is:(784,)
# Iteration-276 the shape of inputs is:(784,)
# Iteration-277 the shape of inputs is:(784,)
# Iteration-278 the shape of inputs is:(784,)
# Iteration-279 the shape of inputs is:(784,)
# Iteration-280 the shape of inputs is:(784,)
# Iteration-281 the shape of inputs is:(784,)
# Iteration-282 the shape of inputs is:(784,)
# Iteration-283 the shape of inputs is:(784,)
# Iteration-284 the shape of inputs is:(784,)
# Iteration-285 the shape of inputs is:(784,)
# Iteration-286 the shape of inputs is:(784,)
# Iteration-287 the shape of inputs is:(784,)
# Iteration-288 the shape of inputs is:(784,)
# Iteration-289 the shape of inputs is:(784,)
# Iteration-290 the shape of inputs is:(784,)
# Iteration-291 the shape of inputs is:(784,)
# Iteration-292 the shape of inputs is:(784,)
# Iteration-293 the shape of inputs is:(784,)
# Iteration-294 the shape of inputs is:(784,)
# Iteration-295 the shape of inputs is:(784,)
# Iteration-296 the shape of inputs is:(784,)
# Iteration-297 the shape of inputs is:(784,)
# Iteration-298 the shape of inputs is:(784,)
# Iteration-299 the shape of inputs is:(784,)
# Iteration-300 the shape of inputs is:(784,)
# Iteration-301 the shape of inputs is:(784,)
# Iteration-302 the shape of inputs is:(784,)
# Iteration-303 the shape of inputs is:(784,)
# Iteration-304 the shape of inputs is:(784,)
# Iteration-305 the shape of inputs is:(784,)
# Iteration-306 the shape of inputs is:(784,)
# Iteration-307 the shape of inputs is:(784,)
# Iteration-308 the shape of inputs is:(784,)
# Iteration-309 the shape of inputs is:(784,)
# Iteration-310 the shape of inputs is:(784,)
# Iteration-311 the shape of inputs is:(784,)
# Iteration-312 the shape of inputs is:(784,)
# Iteration-313 the shape of inputs is:(784,)
# Iteration-314 the shape of inputs is:(784,)
# Iteration-315 the shape of inputs is:(784,)
# Iteration-316 the shape of inputs is:(784,)
# Iteration-317 the shape of inputs is:(784,)
# Iteration-318 the shape of inputs is:(784,)
# Iteration-319 the shape of inputs is:(784,)
# Iteration-320 the shape of inputs is:(784,)
# Iteration-321 the shape of inputs is:(784,)
# Iteration-322 the shape of inputs is:(784,)
# Iteration-323 the shape of inputs is:(784,)
# Iteration-324 the shape of inputs is:(784,)
# Iteration-325 the shape of inputs is:(784,)
# Iteration-326 the shape of inputs is:(784,)
# Iteration-327 the shape of inputs is:(784,)
# Iteration-328 the shape of inputs is:(784,)
# Iteration-329 the shape of inputs is:(784,)
# Iteration-330 the shape of inputs is:(784,)
# Iteration-331 the shape of inputs is:(784,)
# Iteration-332 the shape of inputs is:(784,)
# Iteration-333 the shape of inputs is:(784,)
# Iteration-334 the shape of inputs is:(784,)
# Iteration-335 the shape of inputs is:(784,)
# Iteration-336 the shape of inputs is:(784,)
# Iteration-337 the shape of inputs is:(784,)
# Iteration-338 the shape of inputs is:(784,)
# Iteration-339 the shape of inputs is:(784,)
# Iteration-340 the shape of inputs is:(784,)
# Iteration-341 the shape of inputs is:(784,)
# Iteration-342 the shape of inputs is:(784,)
# Iteration-343 the shape of inputs is:(784,)
# Iteration-344 the shape of inputs is:(784,)
# Iteration-345 the shape of inputs is:(784,)
# Iteration-346 the shape of inputs is:(784,)
# Iteration-347 the shape of inputs is:(784,)
# Iteration-348 the shape of inputs is:(784,)
# Iteration-349 the shape of inputs is:(784,)
# Iteration-350 the shape of inputs is:(784,)
# Iteration-351 the shape of inputs is:(784,)
# Iteration-352 the shape of inputs is:(784,)
# Iteration-353 the shape of inputs is:(784,)
# Iteration-354 the shape of inputs is:(784,)
# Iteration-355 the shape of inputs is:(784,)
# Iteration-356 the shape of inputs is:(784,)
# Iteration-357 the shape of inputs is:(784,)
# Iteration-358 the shape of inputs is:(784,)
# Iteration-359 the shape of inputs is:(784,)
# Iteration-360 the shape of inputs is:(784,)
# Iteration-361 the shape of inputs is:(784,)
# Iteration-362 the shape of inputs is:(784,)
# Iteration-363 the shape of inputs is:(784,)
# Iteration-364 the shape of inputs is:(784,)
# Iteration-365 the shape of inputs is:(784,)
# Iteration-366 the shape of inputs is:(784,)
# Iteration-367 the shape of inputs is:(784,)
# Iteration-368 the shape of inputs is:(784,)
# Iteration-369 the shape of inputs is:(784,)
# Iteration-370 the shape of inputs is:(784,)
# Iteration-371 the shape of inputs is:(784,)
# Iteration-372 the shape of inputs is:(784,)
# Iteration-373 the shape of inputs is:(784,)
# Iteration-374 the shape of inputs is:(784,)
# Iteration-375 the shape of inputs is:(784,)
# Iteration-376 the shape of inputs is:(784,)
# Iteration-377 the shape of inputs is:(784,)
# Iteration-378 the shape of inputs is:(784,)
# Iteration-379 the shape of inputs is:(784,)
# Iteration-380 the shape of inputs is:(784,)
# Iteration-381 the shape of inputs is:(784,)
# Iteration-382 the shape of inputs is:(784,)
# Iteration-383 the shape of inputs is:(784,)
# Iteration-384 the shape of inputs is:(784,)
# Iteration-385 the shape of inputs is:(784,)
# Iteration-386 the shape of inputs is:(784,)
# Iteration-387 the shape of inputs is:(784,)
# Iteration-388 the shape of inputs is:(784,)
# Iteration-389 the shape of inputs is:(784,)
# Iteration-390 the shape of inputs is:(784,)
# Iteration-391 the shape of inputs is:(784,)
# Iteration-392 the shape of inputs is:(784,)
# Iteration-393 the shape of inputs is:(784,)
# Iteration-394 the shape of inputs is:(784,)
# Iteration-395 the shape of inputs is:(784,)
# Iteration-396 the shape of inputs is:(784,)
# Iteration-397 the shape of inputs is:(784,)
# Iteration-398 the shape of inputs is:(784,)
# Iteration-399 the shape of inputs is:(784,)
# Iteration-400 the shape of inputs is:(784,)
# Iteration-401 the shape of inputs is:(784,)
# Iteration-402 the shape of inputs is:(784,)
# Iteration-403 the shape of inputs is:(784,)
# Iteration-404 the shape of inputs is:(784,)
# Iteration-405 the shape of inputs is:(784,)
# Iteration-406 the shape of inputs is:(784,)
# Iteration-407 the shape of inputs is:(784,)
# Iteration-408 the shape of inputs is:(784,)
# Iteration-409 the shape of inputs is:(784,)
# Iteration-410 the shape of inputs is:(784,)
# Iteration-411 the shape of inputs is:(784,)
# Iteration-412 the shape of inputs is:(784,)
# Iteration-413 the shape of inputs is:(784,)
# Iteration-414 the shape of inputs is:(784,)
# Iteration-415 the shape of inputs is:(784,)
# Iteration-416 the shape of inputs is:(784,)
# Iteration-417 the shape of inputs is:(784,)
# Iteration-418 the shape of inputs is:(784,)
# Iteration-419 the shape of inputs is:(784,)
# Iteration-420 the shape of inputs is:(784,)
# Iteration-421 the shape of inputs is:(784,)
# Iteration-422 the shape of inputs is:(784,)
# Iteration-423 the shape of inputs is:(784,)
# Iteration-424 the shape of inputs is:(784,)
# Iteration-425 the shape of inputs is:(784,)
# Iteration-426 the shape of inputs is:(784,)
# Iteration-427 the shape of inputs is:(784,)
# Iteration-428 the shape of inputs is:(784,)
# Iteration-429 the shape of inputs is:(784,)
# Iteration-430 the shape of inputs is:(784,)
# Iteration-431 the shape of inputs is:(784,)
# Iteration-432 the shape of inputs is:(784,)
# Iteration-433 the shape of inputs is:(784,)
# Iteration-434 the shape of inputs is:(784,)
# Iteration-435 the shape of inputs is:(784,)
# Iteration-436 the shape of inputs is:(784,)
# Iteration-437 the shape of inputs is:(784,)
# Iteration-438 the shape of inputs is:(784,)
# Iteration-439 the shape of inputs is:(784,)
# Iteration-440 the shape of inputs is:(784,)
# Iteration-441 the shape of inputs is:(784,)
# Iteration-442 the shape of inputs is:(784,)
# Iteration-443 the shape of inputs is:(784,)
# Iteration-444 the shape of inputs is:(784,)
# Iteration-445 the shape of inputs is:(784,)
# Iteration-446 the shape of inputs is:(784,)
# Iteration-447 the shape of inputs is:(784,)
# Iteration-448 the shape of inputs is:(784,)
# Iteration-449 the shape of inputs is:(784,)
# Iteration-450 the shape of inputs is:(784,)
# Iteration-451 the shape of inputs is:(784,)
# Iteration-452 the shape of inputs is:(784,)
# Iteration-453 the shape of inputs is:(784,)
# Iteration-454 the shape of inputs is:(784,)
# Iteration-455 the shape of inputs is:(784,)
# Iteration-456 the shape of inputs is:(784,)
# Iteration-457 the shape of inputs is:(784,)
# Iteration-458 the shape of inputs is:(784,)
# Iteration-459 the shape of inputs is:(784,)
# Iteration-460 the shape of inputs is:(784,)
# Iteration-461 the shape of inputs is:(784,)
# Iteration-462 the shape of inputs is:(784,)
# Iteration-463 the shape of inputs is:(784,)
# Iteration-464 the shape of inputs is:(784,)
# Iteration-465 the shape of inputs is:(784,)
# Iteration-466 the shape of inputs is:(784,)
# Iteration-467 the shape of inputs is:(784,)
# Iteration-468 the shape of inputs is:(784,)
# Iteration-469 the shape of inputs is:(784,)
# Iteration-470 the shape of inputs is:(784,)
# Iteration-471 the shape of inputs is:(784,)
# Iteration-472 the shape of inputs is:(784,)
# Iteration-473 the shape of inputs is:(784,)
# Iteration-474 the shape of inputs is:(784,)
# Iteration-475 the shape of inputs is:(784,)
# Iteration-476 the shape of inputs is:(784,)
# Iteration-477 the shape of inputs is:(784,)
# Iteration-478 the shape of inputs is:(784,)
# Iteration-479 the shape of inputs is:(784,)
# Iteration-480 the shape of inputs is:(784,)
# Iteration-481 the shape of inputs is:(784,)
# Iteration-482 the shape of inputs is:(784,)
# Iteration-483 the shape of inputs is:(784,)
# Iteration-484 the shape of inputs is:(784,)
# Iteration-485 the shape of inputs is:(784,)
# Iteration-486 the shape of inputs is:(784,)
# Iteration-487 the shape of inputs is:(784,)
# Iteration-488 the shape of inputs is:(784,)
# Iteration-489 the shape of inputs is:(784,)
# Iteration-490 the shape of inputs is:(784,)
# Iteration-491 the shape of inputs is:(784,)
# Iteration-492 the shape of inputs is:(784,)
# Iteration-493 the shape of inputs is:(784,)
# Iteration-494 the shape of inputs is:(784,)
# Iteration-495 the shape of inputs is:(784,)
# Iteration-496 the shape of inputs is:(784,)
# Iteration-497 the shape of inputs is:(784,)
# Iteration-498 the shape of inputs is:(784,)
# Iteration-499 the shape of inputs is:(784,)
# Iteration-500 the shape of inputs is:(784,)
# Iteration-501 the shape of inputs is:(784,)
# Iteration-502 the shape of inputs is:(784,)
# Iteration-503 the shape of inputs is:(784,)
# Iteration-504 the shape of inputs is:(784,)
# Iteration-505 the shape of inputs is:(784,)
# Iteration-506 the shape of inputs is:(784,)
# Iteration-507 the shape of inputs is:(784,)
# Iteration-508 the shape of inputs is:(784,)
# Iteration-509 the shape of inputs is:(784,)
# Iteration-510 the shape of inputs is:(784,)
# Iteration-511 the shape of inputs is:(784,)
# Iteration-512 the shape of inputs is:(784,)
# Iteration-513 the shape of inputs is:(784,)
# Iteration-514 the shape of inputs is:(784,)
# Iteration-515 the shape of inputs is:(784,)
# Iteration-516 the shape of inputs is:(784,)
# Iteration-517 the shape of inputs is:(784,)
# Iteration-518 the shape of inputs is:(784,)
# Iteration-519 the shape of inputs is:(784,)
# Iteration-520 the shape of inputs is:(784,)
# Iteration-521 the shape of inputs is:(784,)
# Iteration-522 the shape of inputs is:(784,)
# Iteration-523 the shape of inputs is:(784,)
# Iteration-524 the shape of inputs is:(784,)
# Iteration-525 the shape of inputs is:(784,)
# Iteration-526 the shape of inputs is:(784,)
# Iteration-527 the shape of inputs is:(784,)
# Iteration-528 the shape of inputs is:(784,)
# Iteration-529 the shape of inputs is:(784,)
# Iteration-530 the shape of inputs is:(784,)
# Iteration-531 the shape of inputs is:(784,)
# Iteration-532 the shape of inputs is:(784,)
# Iteration-533 the shape of inputs is:(784,)
# Iteration-534 the shape of inputs is:(784,)
# Iteration-535 the shape of inputs is:(784,)
# Iteration-536 the shape of inputs is:(784,)
# Iteration-537 the shape of inputs is:(784,)
# Iteration-538 the shape of inputs is:(784,)
# Iteration-539 the shape of inputs is:(784,)
# Iteration-540 the shape of inputs is:(784,)
# Iteration-541 the shape of inputs is:(784,)
# Iteration-542 the shape of inputs is:(784,)
# Iteration-543 the shape of inputs is:(784,)
# Iteration-544 the shape of inputs is:(784,)
# Iteration-545 the shape of inputs is:(784,)
# Iteration-546 the shape of inputs is:(784,)
# Iteration-547 the shape of inputs is:(784,)
# Iteration-548 the shape of inputs is:(784,)
# Iteration-549 the shape of inputs is:(784,)
# Iteration-550 the shape of inputs is:(784,)
# Iteration-551 the shape of inputs is:(784,)
# Iteration-552 the shape of inputs is:(784,)
# Iteration-553 the shape of inputs is:(784,)
# Iteration-554 the shape of inputs is:(784,)
# Iteration-555 the shape of inputs is:(784,)
# Iteration-556 the shape of inputs is:(784,)
# Iteration-557 the shape of inputs is:(784,)
# Iteration-558 the shape of inputs is:(784,)
# Iteration-559 the shape of inputs is:(784,)
# Iteration-560 the shape of inputs is:(784,)
# Iteration-561 the shape of inputs is:(784,)
# Iteration-562 the shape of inputs is:(784,)
# Iteration-563 the shape of inputs is:(784,)
# Iteration-564 the shape of inputs is:(784,)
# Iteration-565 the shape of inputs is:(784,)
# Iteration-566 the shape of inputs is:(784,)
# Iteration-567 the shape of inputs is:(784,)
# Iteration-568 the shape of inputs is:(784,)
# Iteration-569 the shape of inputs is:(784,)
# Iteration-570 the shape of inputs is:(784,)
# Iteration-571 the shape of inputs is:(784,)
# Iteration-572 the shape of inputs is:(784,)
# Iteration-573 the shape of inputs is:(784,)
# Iteration-574 the shape of inputs is:(784,)
# Iteration-575 the shape of inputs is:(784,)
# Iteration-576 the shape of inputs is:(784,)
# Iteration-577 the shape of inputs is:(784,)
# Iteration-578 the shape of inputs is:(784,)
# Iteration-579 the shape of inputs is:(784,)
# Iteration-580 the shape of inputs is:(784,)
# Iteration-581 the shape of inputs is:(784,)
# Iteration-582 the shape of inputs is:(784,)
# Iteration-583 the shape of inputs is:(784,)
# Iteration-584 the shape of inputs is:(784,)
# Iteration-585 the shape of inputs is:(784,)
# Iteration-586 the shape of inputs is:(784,)
# Iteration-587 the shape of inputs is:(784,)
# Iteration-588 the shape of inputs is:(784,)
# Iteration-589 the shape of inputs is:(784,)
# Iteration-590 the shape of inputs is:(784,)
# Iteration-591 the shape of inputs is:(784,)
# Iteration-592 the shape of inputs is:(784,)
# Iteration-593 the shape of inputs is:(784,)
# Iteration-594 the shape of inputs is:(784,)
# Iteration-595 the shape of inputs is:(784,)
# Iteration-596 the shape of inputs is:(784,)
# Iteration-597 the shape of inputs is:(784,)
# Iteration-598 the shape of inputs is:(784,)
# Iteration-599 the shape of inputs is:(784,)
# Iteration-600 the shape of inputs is:(784,)
# Iteration-601 the shape of inputs is:(784,)
# Iteration-602 the shape of inputs is:(784,)
# Iteration-603 the shape of inputs is:(784,)
# Iteration-604 the shape of inputs is:(784,)
# Iteration-605 the shape of inputs is:(784,)
# Iteration-606 the shape of inputs is:(784,)
# Iteration-607 the shape of inputs is:(784,)
# Iteration-608 the shape of inputs is:(784,)
# Iteration-609 the shape of inputs is:(784,)
# Iteration-610 the shape of inputs is:(784,)
# Iteration-611 the shape of inputs is:(784,)
# Iteration-612 the shape of inputs is:(784,)
# Iteration-613 the shape of inputs is:(784,)
# Iteration-614 the shape of inputs is:(784,)
# Iteration-615 the shape of inputs is:(784,)
# Iteration-616 the shape of inputs is:(784,)
# Iteration-617 the shape of inputs is:(784,)
# Iteration-618 the shape of inputs is:(784,)
# Iteration-619 the shape of inputs is:(784,)
# Iteration-620 the shape of inputs is:(784,)
# Iteration-621 the shape of inputs is:(784,)
# Iteration-622 the shape of inputs is:(784,)
# Iteration-623 the shape of inputs is:(784,)
# Iteration-624 the shape of inputs is:(784,)
# Iteration-625 the shape of inputs is:(784,)
# Iteration-626 the shape of inputs is:(784,)
# Iteration-627 the shape of inputs is:(784,)
# Iteration-628 the shape of inputs is:(784,)
# Iteration-629 the shape of inputs is:(784,)
# Iteration-630 the shape of inputs is:(784,)
# Iteration-631 the shape of inputs is:(784,)
# Iteration-632 the shape of inputs is:(784,)
# Iteration-633 the shape of inputs is:(784,)
# Iteration-634 the shape of inputs is:(784,)
# Iteration-635 the shape of inputs is:(784,)
# Iteration-636 the shape of inputs is:(784,)
# Iteration-637 the shape of inputs is:(784,)
# Iteration-638 the shape of inputs is:(784,)
# Iteration-639 the shape of inputs is:(784,)
# Iteration-640 the shape of inputs is:(784,)
# Iteration-641 the shape of inputs is:(784,)
# Iteration-642 the shape of inputs is:(784,)
# Iteration-643 the shape of inputs is:(784,)
# Iteration-644 the shape of inputs is:(784,)
# Iteration-645 the shape of inputs is:(784,)
# Iteration-646 the shape of inputs is:(784,)
# Iteration-647 the shape of inputs is:(784,)
# Iteration-648 the shape of inputs is:(784,)
# Iteration-649 the shape of inputs is:(784,)
# Iteration-650 the shape of inputs is:(784,)
# Iteration-651 the shape of inputs is:(784,)
# Iteration-652 the shape of inputs is:(784,)
# Iteration-653 the shape of inputs is:(784,)
# Iteration-654 the shape of inputs is:(784,)
# Iteration-655 the shape of inputs is:(784,)
# Iteration-656 the shape of inputs is:(784,)
# Iteration-657 the shape of inputs is:(784,)
# Iteration-658 the shape of inputs is:(784,)
# Iteration-659 the shape of inputs is:(784,)
# Iteration-660 the shape of inputs is:(784,)
# Iteration-661 the shape of inputs is:(784,)
# Iteration-662 the shape of inputs is:(784,)
# Iteration-663 the shape of inputs is:(784,)
# Iteration-664 the shape of inputs is:(784,)
# Iteration-665 the shape of inputs is:(784,)
# Iteration-666 the shape of inputs is:(784,)
# Iteration-667 the shape of inputs is:(784,)
# Iteration-668 the shape of inputs is:(784,)
# Iteration-669 the shape of inputs is:(784,)
# Iteration-670 the shape of inputs is:(784,)
# Iteration-671 the shape of inputs is:(784,)
# Iteration-672 the shape of inputs is:(784,)
# Iteration-673 the shape of inputs is:(784,)
# Iteration-674 the shape of inputs is:(784,)
# Iteration-675 the shape of inputs is:(784,)
# Iteration-676 the shape of inputs is:(784,)
# Iteration-677 the shape of inputs is:(784,)
# Iteration-678 the shape of inputs is:(784,)
# Iteration-679 the shape of inputs is:(784,)
# Iteration-680 the shape of inputs is:(784,)
# Iteration-681 the shape of inputs is:(784,)
# Iteration-682 the shape of inputs is:(784,)
# Iteration-683 the shape of inputs is:(784,)
# Iteration-684 the shape of inputs is:(784,)
# Iteration-685 the shape of inputs is:(784,)
# Iteration-686 the shape of inputs is:(784,)
# Iteration-687 the shape of inputs is:(784,)
# Iteration-688 the shape of inputs is:(784,)
# Iteration-689 the shape of inputs is:(784,)
# Iteration-690 the shape of inputs is:(784,)
# Iteration-691 the shape of inputs is:(784,)
# Iteration-692 the shape of inputs is:(784,)
# Iteration-693 the shape of inputs is:(784,)
# Iteration-694 the shape of inputs is:(784,)
# Iteration-695 the shape of inputs is:(784,)
# Iteration-696 the shape of inputs is:(784,)
# Iteration-697 the shape of inputs is:(784,)
# Iteration-698 the shape of inputs is:(784,)
# Iteration-699 the shape of inputs is:(784,)
# Iteration-700 the shape of inputs is:(784,)
# Iteration-701 the shape of inputs is:(784,)
# Iteration-702 the shape of inputs is:(784,)
# Iteration-703 the shape of inputs is:(784,)
# Iteration-704 the shape of inputs is:(784,)
# Iteration-705 the shape of inputs is:(784,)
# Iteration-706 the shape of inputs is:(784,)
# Iteration-707 the shape of inputs is:(784,)
# Iteration-708 the shape of inputs is:(784,)
# Iteration-709 the shape of inputs is:(784,)
# Iteration-710 the shape of inputs is:(784,)
# Iteration-711 the shape of inputs is:(784,)
# Iteration-712 the shape of inputs is:(784,)
# Iteration-713 the shape of inputs is:(784,)
# Iteration-714 the shape of inputs is:(784,)
# Iteration-715 the shape of inputs is:(784,)
# Iteration-716 the shape of inputs is:(784,)
# Iteration-717 the shape of inputs is:(784,)
# Iteration-718 the shape of inputs is:(784,)
# Iteration-719 the shape of inputs is:(784,)
# Iteration-720 the shape of inputs is:(784,)
# Iteration-721 the shape of inputs is:(784,)
# Iteration-722 the shape of inputs is:(784,)
# Iteration-723 the shape of inputs is:(784,)
# Iteration-724 the shape of inputs is:(784,)
# Iteration-725 the shape of inputs is:(784,)
# Iteration-726 the shape of inputs is:(784,)
# Iteration-727 the shape of inputs is:(784,)
# Iteration-728 the shape of inputs is:(784,)
# Iteration-729 the shape of inputs is:(784,)
# Iteration-730 the shape of inputs is:(784,)
# Iteration-731 the shape of inputs is:(784,)
# Iteration-732 the shape of inputs is:(784,)
# Iteration-733 the shape of inputs is:(784,)
# Iteration-734 the shape of inputs is:(784,)
# Iteration-735 the shape of inputs is:(784,)
# Iteration-736 the shape of inputs is:(784,)
# Iteration-737 the shape of inputs is:(784,)
# Iteration-738 the shape of inputs is:(784,)
# Iteration-739 the shape of inputs is:(784,)
# Iteration-740 the shape of inputs is:(784,)
# Iteration-741 the shape of inputs is:(784,)
# Iteration-742 the shape of inputs is:(784,)
# Iteration-743 the shape of inputs is:(784,)
# Iteration-744 the shape of inputs is:(784,)
# Iteration-745 the shape of inputs is:(784,)
# Iteration-746 the shape of inputs is:(784,)
# Iteration-747 the shape of inputs is:(784,)
# Iteration-748 the shape of inputs is:(784,)
# Iteration-749 the shape of inputs is:(784,)
# Iteration-750 the shape of inputs is:(784,)
# Iteration-751 the shape of inputs is:(784,)
# Iteration-752 the shape of inputs is:(784,)
# Iteration-753 the shape of inputs is:(784,)
# Iteration-754 the shape of inputs is:(784,)
# Iteration-755 the shape of inputs is:(784,)
# Iteration-756 the shape of inputs is:(784,)
# Iteration-757 the shape of inputs is:(784,)
# Iteration-758 the shape of inputs is:(784,)
# Iteration-759 the shape of inputs is:(784,)
# Iteration-760 the shape of inputs is:(784,)
# Iteration-761 the shape of inputs is:(784,)
# Iteration-762 the shape of inputs is:(784,)
# Iteration-763 the shape of inputs is:(784,)
# Iteration-764 the shape of inputs is:(784,)
# Iteration-765 the shape of inputs is:(784,)
# Iteration-766 the shape of inputs is:(784,)
# Iteration-767 the shape of inputs is:(784,)
# Iteration-768 the shape of inputs is:(784,)
# Iteration-769 the shape of inputs is:(784,)
# Iteration-770 the shape of inputs is:(784,)
# Iteration-771 the shape of inputs is:(784,)
# Iteration-772 the shape of inputs is:(784,)
# Iteration-773 the shape of inputs is:(784,)
# Iteration-774 the shape of inputs is:(784,)
# Iteration-775 the shape of inputs is:(784,)
# Iteration-776 the shape of inputs is:(784,)
# Iteration-777 the shape of inputs is:(784,)
# Iteration-778 the shape of inputs is:(784,)
# Iteration-779 the shape of inputs is:(784,)
# Iteration-780 the shape of inputs is:(784,)
# Iteration-781 the shape of inputs is:(784,)
# Iteration-782 the shape of inputs is:(784,)
# Iteration-783 the shape of inputs is:(784,)
# Iteration-784 the shape of inputs is:(784,)
# Iteration-785 the shape of inputs is:(784,)
# Iteration-786 the shape of inputs is:(784,)
# Iteration-787 the shape of inputs is:(784,)
# Iteration-788 the shape of inputs is:(784,)
# Iteration-789 the shape of inputs is:(784,)
# Iteration-790 the shape of inputs is:(784,)
# Iteration-791 the shape of inputs is:(784,)
# Iteration-792 the shape of inputs is:(784,)
# Iteration-793 the shape of inputs is:(784,)
# Iteration-794 the shape of inputs is:(784,)
# Iteration-795 the shape of inputs is:(784,)
# Iteration-796 the shape of inputs is:(784,)
# Iteration-797 the shape of inputs is:(784,)
# Iteration-798 the shape of inputs is:(784,)
# Iteration-799 the shape of inputs is:(784,)
# Iteration-800 the shape of inputs is:(784,)
# Iteration-801 the shape of inputs is:(784,)
# Iteration-802 the shape of inputs is:(784,)
# Iteration-803 the shape of inputs is:(784,)
# Iteration-804 the shape of inputs is:(784,)
# Iteration-805 the shape of inputs is:(784,)
# Iteration-806 the shape of inputs is:(784,)
# Iteration-807 the shape of inputs is:(784,)
# Iteration-808 the shape of inputs is:(784,)
# Iteration-809 the shape of inputs is:(784,)
# Iteration-810 the shape of inputs is:(784,)
# Iteration-811 the shape of inputs is:(784,)
# Iteration-812 the shape of inputs is:(784,)
# Iteration-813 the shape of inputs is:(784,)
# Iteration-814 the shape of inputs is:(784,)
# Iteration-815 the shape of inputs is:(784,)
# Iteration-816 the shape of inputs is:(784,)
# Iteration-817 the shape of inputs is:(784,)
# Iteration-818 the shape of inputs is:(784,)
# Iteration-819 the shape of inputs is:(784,)
# Iteration-820 the shape of inputs is:(784,)
# Iteration-821 the shape of inputs is:(784,)
# Iteration-822 the shape of inputs is:(784,)
# Iteration-823 the shape of inputs is:(784,)
# Iteration-824 the shape of inputs is:(784,)
# Iteration-825 the shape of inputs is:(784,)
# Iteration-826 the shape of inputs is:(784,)
# Iteration-827 the shape of inputs is:(784,)
# Iteration-828 the shape of inputs is:(784,)
# Iteration-829 the shape of inputs is:(784,)
# Iteration-830 the shape of inputs is:(784,)
# Iteration-831 the shape of inputs is:(784,)
# Iteration-832 the shape of inputs is:(784,)
# Iteration-833 the shape of inputs is:(784,)
# Iteration-834 the shape of inputs is:(784,)
# Iteration-835 the shape of inputs is:(784,)
# Iteration-836 the shape of inputs is:(784,)
# Iteration-837 the shape of inputs is:(784,)
# Iteration-838 the shape of inputs is:(784,)
# Iteration-839 the shape of inputs is:(784,)
# Iteration-840 the shape of inputs is:(784,)
# Iteration-841 the shape of inputs is:(784,)
# Iteration-842 the shape of inputs is:(784,)
# Iteration-843 the shape of inputs is:(784,)
# Iteration-844 the shape of inputs is:(784,)
# Iteration-845 the shape of inputs is:(784,)
# Iteration-846 the shape of inputs is:(784,)
# Iteration-847 the shape of inputs is:(784,)
# Iteration-848 the shape of inputs is:(784,)
# Iteration-849 the shape of inputs is:(784,)
# Iteration-850 the shape of inputs is:(784,)
# Iteration-851 the shape of inputs is:(784,)
# Iteration-852 the shape of inputs is:(784,)
# Iteration-853 the shape of inputs is:(784,)
# Iteration-854 the shape of inputs is:(784,)
# Iteration-855 the shape of inputs is:(784,)
# Iteration-856 the shape of inputs is:(784,)
# Iteration-857 the shape of inputs is:(784,)
# Iteration-858 the shape of inputs is:(784,)
# Iteration-859 the shape of inputs is:(784,)
# Iteration-860 the shape of inputs is:(784,)
# Iteration-861 the shape of inputs is:(784,)
# Iteration-862 the shape of inputs is:(784,)
# Iteration-863 the shape of inputs is:(784,)
# Iteration-864 the shape of inputs is:(784,)
# Iteration-865 the shape of inputs is:(784,)
# Iteration-866 the shape of inputs is:(784,)
# Iteration-867 the shape of inputs is:(784,)
# Iteration-868 the shape of inputs is:(784,)
# Iteration-869 the shape of inputs is:(784,)
# Iteration-870 the shape of inputs is:(784,)
# Iteration-871 the shape of inputs is:(784,)
# Iteration-872 the shape of inputs is:(784,)
# Iteration-873 the shape of inputs is:(784,)
# Iteration-874 the shape of inputs is:(784,)
# Iteration-875 the shape of inputs is:(784,)
# Iteration-876 the shape of inputs is:(784,)
# Iteration-877 the shape of inputs is:(784,)
# Iteration-878 the shape of inputs is:(784,)
# Iteration-879 the shape of inputs is:(784,)
# Iteration-880 the shape of inputs is:(784,)
# Iteration-881 the shape of inputs is:(784,)
# Iteration-882 the shape of inputs is:(784,)
# Iteration-883 the shape of inputs is:(784,)
# Iteration-884 the shape of inputs is:(784,)
# Iteration-885 the shape of inputs is:(784,)
# Iteration-886 the shape of inputs is:(784,)
# Iteration-887 the shape of inputs is:(784,)
# Iteration-888 the shape of inputs is:(784,)
# Iteration-889 the shape of inputs is:(784,)
# Iteration-890 the shape of inputs is:(784,)
# Iteration-891 the shape of inputs is:(784,)
# Iteration-892 the shape of inputs is:(784,)
# Iteration-893 the shape of inputs is:(784,)
# Iteration-894 the shape of inputs is:(784,)
# Iteration-895 the shape of inputs is:(784,)
# Iteration-896 the shape of inputs is:(784,)
# Iteration-897 the shape of inputs is:(784,)
# Iteration-898 the shape of inputs is:(784,)
# Iteration-899 the shape of inputs is:(784,)
# Iteration-900 the shape of inputs is:(784,)
# Iteration-901 the shape of inputs is:(784,)
# Iteration-902 the shape of inputs is:(784,)
# Iteration-903 the shape of inputs is:(784,)
# Iteration-904 the shape of inputs is:(784,)
# Iteration-905 the shape of inputs is:(784,)
# Iteration-906 the shape of inputs is:(784,)
# Iteration-907 the shape of inputs is:(784,)
# Iteration-908 the shape of inputs is:(784,)
# Iteration-909 the shape of inputs is:(784,)
# Iteration-910 the shape of inputs is:(784,)
# Iteration-911 the shape of inputs is:(784,)
# Iteration-912 the shape of inputs is:(784,)
# Iteration-913 the shape of inputs is:(784,)
# Iteration-914 the shape of inputs is:(784,)
# Iteration-915 the shape of inputs is:(784,)
# Iteration-916 the shape of inputs is:(784,)
# Iteration-917 the shape of inputs is:(784,)
# Iteration-918 the shape of inputs is:(784,)
# Iteration-919 the shape of inputs is:(784,)
# Iteration-920 the shape of inputs is:(784,)
# Iteration-921 the shape of inputs is:(784,)
# Iteration-922 the shape of inputs is:(784,)
# Iteration-923 the shape of inputs is:(784,)
# Iteration-924 the shape of inputs is:(784,)
# Iteration-925 the shape of inputs is:(784,)
# Iteration-926 the shape of inputs is:(784,)
# Iteration-927 the shape of inputs is:(784,)
# Iteration-928 the shape of inputs is:(784,)
# Iteration-929 the shape of inputs is:(784,)
# Iteration-930 the shape of inputs is:(784,)
# Iteration-931 the shape of inputs is:(784,)
# Iteration-932 the shape of inputs is:(784,)
# Iteration-933 the shape of inputs is:(784,)
# Iteration-934 the shape of inputs is:(784,)
# Iteration-935 the shape of inputs is:(784,)
# Iteration-936 the shape of inputs is:(784,)
# Iteration-937 the shape of inputs is:(784,)
# Iteration-938 the shape of inputs is:(784,)
# Iteration-939 the shape of inputs is:(784,)
# Iteration-940 the shape of inputs is:(784,)
# Iteration-941 the shape of inputs is:(784,)
# Iteration-942 the shape of inputs is:(784,)
# Iteration-943 the shape of inputs is:(784,)
# Iteration-944 the shape of inputs is:(784,)
# Iteration-945 the shape of inputs is:(784,)
# Iteration-946 the shape of inputs is:(784,)
# Iteration-947 the shape of inputs is:(784,)
# Iteration-948 the shape of inputs is:(784,)
# Iteration-949 the shape of inputs is:(784,)
# Iteration-950 the shape of inputs is:(784,)
# Iteration-951 the shape of inputs is:(784,)
# Iteration-952 the shape of inputs is:(784,)
# Iteration-953 the shape of inputs is:(784,)
# Iteration-954 the shape of inputs is:(784,)
# Iteration-955 the shape of inputs is:(784,)
# Iteration-956 the shape of inputs is:(784,)
# Iteration-957 the shape of inputs is:(784,)
# Iteration-958 the shape of inputs is:(784,)
# Iteration-959 the shape of inputs is:(784,)
# Iteration-960 the shape of inputs is:(784,)
# Iteration-961 the shape of inputs is:(784,)
# Iteration-962 the shape of inputs is:(784,)
# Iteration-963 the shape of inputs is:(784,)
# Iteration-964 the shape of inputs is:(784,)
# Iteration-965 the shape of inputs is:(784,)
# Iteration-966 the shape of inputs is:(784,)
# Iteration-967 the shape of inputs is:(784,)
# Iteration-968 the shape of inputs is:(784,)
# Iteration-969 the shape of inputs is:(784,)
# Iteration-970 the shape of inputs is:(784,)
# Iteration-971 the shape of inputs is:(784,)
# Iteration-972 the shape of inputs is:(784,)
# Iteration-973 the shape of inputs is:(784,)
# Iteration-974 the shape of inputs is:(784,)
# Iteration-975 the shape of inputs is:(784,)
# Iteration-976 the shape of inputs is:(784,)
# Iteration-977 the shape of inputs is:(784,)
# Iteration-978 the shape of inputs is:(784,)
# Iteration-979 the shape of inputs is:(784,)
# Iteration-980 the shape of inputs is:(784,)
# Iteration-981 the shape of inputs is:(784,)
# Iteration-982 the shape of inputs is:(784,)
# Iteration-983 the shape of inputs is:(784,)
# Iteration-984 the shape of inputs is:(784,)
# Iteration-985 the shape of inputs is:(784,)
# Iteration-986 the shape of inputs is:(784,)
# Iteration-987 the shape of inputs is:(784,)
# Iteration-988 the shape of inputs is:(784,)
# Iteration-989 the shape of inputs is:(784,)
# Iteration-990 the shape of inputs is:(784,)
# Iteration-991 the shape of inputs is:(784,)
# Iteration-992 the shape of inputs is:(784,)
# Iteration-993 the shape of inputs is:(784,)
# Iteration-994 the shape of inputs is:(784,)
# Iteration-995 the shape of inputs is:(784,)
# Iteration-996 the shape of inputs is:(784,)
# Iteration-997 the shape of inputs is:(784,)
# Iteration-998 the shape of inputs is:(784,)
# Iteration-999 the shape of inputs is:(784,)
# Iteration-1000 the shape of inputs is:(784,)
# Iteration-1001 the shape of inputs is:(784,)
# Iteration-1002 the shape of inputs is:(784,)
# Iteration-1003 the shape of inputs is:(784,)
# Iteration-1004 the shape of inputs is:(784,)
# Iteration-1005 the shape of inputs is:(784,)
# Iteration-1006 the shape of inputs is:(784,)
# Iteration-1007 the shape of inputs is:(784,)
# Iteration-1008 the shape of inputs is:(784,)
# Iteration-1009 the shape of inputs is:(784,)
# Iteration-1010 the shape of inputs is:(784,)
# Iteration-1011 the shape of inputs is:(784,)
# Iteration-1012 the shape of inputs is:(784,)
# Iteration-1013 the shape of inputs is:(784,)
# Iteration-1014 the shape of inputs is:(784,)
# Iteration-1015 the shape of inputs is:(784,)
# Iteration-1016 the shape of inputs is:(784,)
# Iteration-1017 the shape of inputs is:(784,)
# Iteration-1018 the shape of inputs is:(784,)
# Iteration-1019 the shape of inputs is:(784,)
# Iteration-1020 the shape of inputs is:(784,)
# Iteration-1021 the shape of inputs is:(784,)
# Iteration-1022 the shape of inputs is:(784,)
# Iteration-1023 the shape of inputs is:(784,)
# Iteration-1024 the shape of inputs is:(784,)
# Iteration-1025 the shape of inputs is:(784,)
# Iteration-1026 the shape of inputs is:(784,)
# Iteration-1027 the shape of inputs is:(784,)
# Iteration-1028 the shape of inputs is:(784,)
# Iteration-1029 the shape of inputs is:(784,)
# Iteration-1030 the shape of inputs is:(784,)
# Iteration-1031 the shape of inputs is:(784,)
# Iteration-1032 the shape of inputs is:(784,)
# Iteration-1033 the shape of inputs is:(784,)
# Iteration-1034 the shape of inputs is:(784,)
# Iteration-1035 the shape of inputs is:(784,)
# Iteration-1036 the shape of inputs is:(784,)
# Iteration-1037 the shape of inputs is:(784,)
# Iteration-1038 the shape of inputs is:(784,)
# Iteration-1039 the shape of inputs is:(784,)
# Iteration-1040 the shape of inputs is:(784,)
# Iteration-1041 the shape of inputs is:(784,)
# Iteration-1042 the shape of inputs is:(784,)
# Iteration-1043 the shape of inputs is:(784,)
# Iteration-1044 the shape of inputs is:(784,)
# Iteration-1045 the shape of inputs is:(784,)
# Iteration-1046 the shape of inputs is:(784,)
# Iteration-1047 the shape of inputs is:(784,)
# Iteration-1048 the shape of inputs is:(784,)
# Iteration-1049 the shape of inputs is:(784,)
# Iteration-1050 the shape of inputs is:(784,)
# Iteration-1051 the shape of inputs is:(784,)
# Iteration-1052 the shape of inputs is:(784,)
# Iteration-1053 the shape of inputs is:(784,)
# Iteration-1054 the shape of inputs is:(784,)
# Iteration-1055 the shape of inputs is:(784,)
# Iteration-1056 the shape of inputs is:(784,)
# Iteration-1057 the shape of inputs is:(784,)
# Iteration-1058 the shape of inputs is:(784,)
# Iteration-1059 the shape of inputs is:(784,)
# Iteration-1060 the shape of inputs is:(784,)
# Iteration-1061 the shape of inputs is:(784,)
# Iteration-1062 the shape of inputs is:(784,)
# Iteration-1063 the shape of inputs is:(784,)
# Iteration-1064 the shape of inputs is:(784,)
# Iteration-1065 the shape of inputs is:(784,)
# Iteration-1066 the shape of inputs is:(784,)
# Iteration-1067 the shape of inputs is:(784,)
# Iteration-1068 the shape of inputs is:(784,)
# Iteration-1069 the shape of inputs is:(784,)
# Iteration-1070 the shape of inputs is:(784,)
# Iteration-1071 the shape of inputs is:(784,)
# Iteration-1072 the shape of inputs is:(784,)
# Iteration-1073 the shape of inputs is:(784,)
# Iteration-1074 the shape of inputs is:(784,)
# Iteration-1075 the shape of inputs is:(784,)
# Iteration-1076 the shape of inputs is:(784,)
# Iteration-1077 the shape of inputs is:(784,)
# Iteration-1078 the shape of inputs is:(784,)
# Iteration-1079 the shape of inputs is:(784,)
# Iteration-1080 the shape of inputs is:(784,)
# Iteration-1081 the shape of inputs is:(784,)
# Iteration-1082 the shape of inputs is:(784,)
# Iteration-1083 the shape of inputs is:(784,)
# Iteration-1084 the shape of inputs is:(784,)
# Iteration-1085 the shape of inputs is:(784,)
# Iteration-1086 the shape of inputs is:(784,)
# Iteration-1087 the shape of inputs is:(784,)
# Iteration-1088 the shape of inputs is:(784,)
# Iteration-1089 the shape of inputs is:(784,)
# Iteration-1090 the shape of inputs is:(784,)
# ...
# Iteration-21267 the shape of inputs is:(784,)
# Iteration-21268 the shape of inputs is:(784,)
# Iteration-21269 the shape of inputs is:(784,)
# Iteration-21270 the shape of inputs is:(784,)
# Iteration-21271 the shape of inputs is:(784,)
# Iteration-21272 the shape of inputs is:(784,)
# Iteration-21273 the shape of inputs is:(784,)
# Iteration-21274 the shape of inputs is:(784,)
# Iteration-21275 the shape of inputs is:(784,)
# Iteration-21276 the shape of inputs is:(784,)
# Iteration-21277 the shape of inputs is:(784,)
# Iteration-21278 the shape of inputs is:(784,)
# Iteration-21279 the shape of inputs is:(784,)
# Iteration-21280 the shape of inputs is:(784,)
# Iteration-21281 the shape of inputs is:(784,)
# Iteration-21282 the shape of inputs is:(784,)
# Iteration-21283 the shape of inputs is:(784,)
# Iteration-21284 the shape of inputs is:(784,)
# Iteration-21285 the shape of inputs is:(784,)
# Iteration-21286 the shape of inputs is:(784,)
# Iteration-21287 the shape of inputs is:(784,)
# Iteration-21288 the shape of inputs is:(784,)
# Iteration-21289 the shape of inputs is:(784,)
# Iteration-21290 the shape of inputs is:(784,)
# Iteration-21291 the shape of inputs is:(784,)
# Iteration-21292 the shape of inputs is:(784,)
# Iteration-21293 the shape of inputs is:(784,)
# Iteration-21294 the shape of inputs is:(784,)
# Iteration-21295 the shape of inputs is:(784,)
# Iteration-21296 the shape of inputs is:(784,)
# Iteration-21297 the shape of inputs is:(784,)
# Iteration-21298 the shape of inputs is:(784,)
# Iteration-21299 the shape of inputs is:(784,)
# Iteration-21300 the shape of inputs is:(784,)
# Iteration-21301 the shape of inputs is:(784,)
# Iteration-21302 the shape of inputs is:(784,)
# Iteration-21303 the shape of inputs is:(784,)
# Iteration-21304 the shape of inputs is:(784,)
# Iteration-21305 the shape of inputs is:(784,)
# Iteration-21306 the shape of inputs is:(784,)
# Iteration-21307 the shape of inputs is:(784,)
# Iteration-21308 the shape of inputs is:(784,)
# Iteration-21309 the shape of inputs is:(784,)
# Iteration-21310 the shape of inputs is:(784,)
# Iteration-21311 the shape of inputs is:(784,)
# Iteration-21312 the shape of inputs is:(784,)
# Iteration-21313 the shape of inputs is:(784,)
# Iteration-21314 the shape of inputs is:(784,)
# Iteration-21315 the shape of inputs is:(784,)
# Iteration-21316 the shape of inputs is:(784,)
# Iteration-21317 the shape of inputs is:(784,)
# Iteration-21318 the shape of inputs is:(784,)
# Iteration-21319 the shape of inputs is:(784,)
# Iteration-21320 the shape of inputs is:(784,)
# Iteration-21321 the shape of inputs is:(784,)
# Iteration-21322 the shape of inputs is:(784,)
# Iteration-21323 the shape of inputs is:(784,)
# Iteration-21324 the shape of inputs is:(784,)
# Iteration-21325 the shape of inputs is:(784,)
# Iteration-21326 the shape of inputs is:(784,)
# Iteration-21327 the shape of inputs is:(784,)
# Iteration-21328 the shape of inputs is:(784,)
# Iteration-21329 the shape of inputs is:(784,)
# Iteration-21330 the shape of inputs is:(784,)
# Iteration-21331 the shape of inputs is:(784,)
# Iteration-21332 the shape of inputs is:(784,)
# Iteration-21333 the shape of inputs is:(784,)
# Iteration-21334 the shape of inputs is:(784,)
# Iteration-21335 the shape of inputs is:(784,)
# Iteration-21336 the shape of inputs is:(784,)
# Iteration-21337 the shape of inputs is:(784,)
# Iteration-21338 the shape of inputs is:(784,)
# Iteration-21339 the shape of inputs is:(784,)
# Iteration-21340 the shape of inputs is:(784,)
# Iteration-21341 the shape of inputs is:(784,)
# Iteration-21342 the shape of inputs is:(784,)
# Iteration-21343 the shape of inputs is:(784,)
# Iteration-21344 the shape of inputs is:(784,)
# Iteration-21345 the shape of inputs is:(784,)
# Iteration-21346 the shape of inputs is:(784,)
# Iteration-21347 the shape of inputs is:(784,)
# Iteration-21348 the shape of inputs is:(784,)
# Iteration-21349 the shape of inputs is:(784,)
# Iteration-21350 the shape of inputs is:(784,)
# Iteration-21351 the shape of inputs is:(784,)
# Iteration-21352 the shape of inputs is:(784,)
# Iteration-21353 the shape of inputs is:(784,)
# Iteration-21354 the shape of inputs is:(784,)
# Iteration-21355 the shape of inputs is:(784,)
# Iteration-21356 the shape of inputs is:(784,)
# Iteration-21357 the shape of inputs is:(784,)
# Iteration-21358 the shape of inputs is:(784,)
# Iteration-21359 the shape of inputs is:(784,)
# Iteration-21360 the shape of inputs is:(784,)
# Iteration-21361 the shape of inputs is:(784,)
# Iteration-21362 the shape of inputs is:(784,)
# Iteration-21363 the shape of inputs is:(784,)
# Iteration-21364 the shape of inputs is:(784,)
# Iteration-21365 the shape of inputs is:(784,)
# Iteration-21366 the shape of inputs is:(784,)
# Iteration-21367 the shape of inputs is:(784,)
# Iteration-21368 the shape of inputs is:(784,)
# Iteration-21369 the shape of inputs is:(784,)
# Iteration-21370 the shape of inputs is:(784,)
# Iteration-21371 the shape of inputs is:(784,)
# Iteration-21372 the shape of inputs is:(784,)
# Iteration-21373 the shape of inputs is:(784,)
# Iteration-21374 the shape of inputs is:(784,)
# Iteration-21375 the shape of inputs is:(784,)
# Iteration-21376 the shape of inputs is:(784,)
# Iteration-21377 the shape of inputs is:(784,)
# Iteration-21378 the shape of inputs is:(784,)
# Iteration-21379 the shape of inputs is:(784,)
# Iteration-21380 the shape of inputs is:(784,)
# Iteration-21381 the shape of inputs is:(784,)
# Iteration-21382 the shape of inputs is:(784,)
# Iteration-21383 the shape of inputs is:(784,)
# Iteration-21384 the shape of inputs is:(784,)
# Iteration-21385 the shape of inputs is:(784,)
# Iteration-21386 the shape of inputs is:(784,)
# Iteration-21387 the shape of inputs is:(784,)
# Iteration-21388 the shape of inputs is:(784,)
# Iteration-21389 the shape of inputs is:(784,)
# Iteration-21390 the shape of inputs is:(784,)
# Iteration-21391 the shape of inputs is:(784,)
# Iteration-21392 the shape of inputs is:(784,)
# Iteration-21393 the shape of inputs is:(784,)
# Iteration-21394 the shape of inputs is:(784,)
# Iteration-21395 the shape of inputs is:(784,)
# Iteration-21396 the shape of inputs is:(784,)
# Iteration-21397 the shape of inputs is:(784,)
# Iteration-21398 the shape of inputs is:(784,)
# Iteration-21399 the shape of inputs is:(784,)
# Iteration-21400 the shape of inputs is:(784,)
# Iteration-21401 the shape of inputs is:(784,)
# Iteration-21402 the shape of inputs is:(784,)
# Iteration-21403 the shape of inputs is:(784,)
# Iteration-21404 the shape of inputs is:(784,)
# Iteration-21405 the shape of inputs is:(784,)
# Iteration-21406 the shape of inputs is:(784,)
# Iteration-21407 the shape of inputs is:(784,)
# Iteration-21408 the shape of inputs is:(784,)
# Iteration-21409 the shape of inputs is:(784,)
# Iteration-21410 the shape of inputs is:(784,)
# Iteration-21411 the shape of inputs is:(784,)
# Iteration-21412 the shape of inputs is:(784,)
# Iteration-21413 the shape of inputs is:(784,)
# Iteration-21414 the shape of inputs is:(784,)
# Iteration-21415 the shape of inputs is:(784,)
# Iteration-21416 the shape of inputs is:(784,)
# Iteration-21417 the shape of inputs is:(784,)
# Iteration-21418 the shape of inputs is:(784,)
# Iteration-21419 the shape of inputs is:(784,)
# Iteration-21420 the shape of inputs is:(784,)
# Iteration-21421 the shape of inputs is:(784,)
# Iteration-21422 the shape of inputs is:(784,)
# Iteration-21423 the shape of inputs is:(784,)
# Iteration-21424 the shape of inputs is:(784,)
# Iteration-21425 the shape of inputs is:(784,)
# Iteration-21426 the shape of inputs is:(784,)
# Iteration-21427 the shape of inputs is:(784,)
# Iteration-21428 the shape of inputs is:(784,)
# Iteration-21429 the shape of inputs is:(784,)
# Iteration-21430 the shape of inputs is:(784,)
# Iteration-21431 the shape of inputs is:(784,)
# Iteration-21432 the shape of inputs is:(784,)
# Iteration-21433 the shape of inputs is:(784,)
# Iteration-21434 the shape of inputs is:(784,)
# Iteration-21435 the shape of inputs is:(784,)
# Iteration-21436 the shape of inputs is:(784,)
# Iteration-21437 the shape of inputs is:(784,)
# Iteration-21438 the shape of inputs is:(784,)
# Iteration-21439 the shape of inputs is:(784,)
# Iteration-21440 the shape of inputs is:(784,)
# Iteration-21441 the shape of inputs is:(784,)
# Iteration-21442 the shape of inputs is:(784,)
# Iteration-21443 the shape of inputs is:(784,)
# Iteration-21444 the shape of inputs is:(784,)
# Iteration-21445 the shape of inputs is:(784,)
# Iteration-21446 the shape of inputs is:(784,)
# Iteration-21447 the shape of inputs is:(784,)
# Iteration-21448 the shape of inputs is:(784,)
# Iteration-21449 the shape of inputs is:(784,)
# Iteration-21450 the shape of inputs is:(784,)
# Iteration-21451 the shape of inputs is:(784,)
# Iteration-21452 the shape of inputs is:(784,)
# Iteration-21453 the shape of inputs is:(784,)
# Iteration-21454 the shape of inputs is:(784,)
# Iteration-21455 the shape of inputs is:(784,)
# Iteration-21456 the shape of inputs is:(784,)
# Iteration-21457 the shape of inputs is:(784,)
# Iteration-21458 the shape of inputs is:(784,)
# Iteration-21459 the shape of inputs is:(784,)
# Iteration-21460 the shape of inputs is:(784,)
# Iteration-21461 the shape of inputs is:(784,)
# Iteration-21462 the shape of inputs is:(784,)
# Iteration-21463 the shape of inputs is:(784,)
# Iteration-21464 the shape of inputs is:(784,)
# Iteration-21465 the shape of inputs is:(784,)
# Iteration-21466 the shape of inputs is:(784,)
# Iteration-21467 the shape of inputs is:(784,)
# Iteration-21468 the shape of inputs is:(784,)
# Iteration-21469 the shape of inputs is:(784,)
# Iteration-21470 the shape of inputs is:(784,)
# Iteration-21471 the shape of inputs is:(784,)
# Iteration-21472 the shape of inputs is:(784,)
# Iteration-21473 the shape of inputs is:(784,)
# Iteration-21474 the shape of inputs is:(784,)
# Iteration-21475 the shape of inputs is:(784,)
# Iteration-21476 the shape of inputs is:(784,)
# Iteration-21477 the shape of inputs is:(784,)
# Iteration-21478 the shape of inputs is:(784,)
# Iteration-21479 the shape of inputs is:(784,)
# Iteration-21480 the shape of inputs is:(784,)
# Iteration-21481 the shape of inputs is:(784,)
# Iteration-21482 the shape of inputs is:(784,)
# Iteration-21483 the shape of inputs is:(784,)
# Iteration-21484 the shape of inputs is:(784,)
# Iteration-21485 the shape of inputs is:(784,)
# Iteration-21486 the shape of inputs is:(784,)
# Iteration-21487 the shape of inputs is:(784,)
# Iteration-21488 the shape of inputs is:(784,)
# Iteration-21489 the shape of inputs is:(784,)
# Iteration-21490 the shape of inputs is:(784,)
# Iteration-21491 the shape of inputs is:(784,)
# Iteration-21492 the shape of inputs is:(784,)
# Iteration-21493 the shape of inputs is:(784,)
# Iteration-21494 the shape of inputs is:(784,)
# Iteration-21495 the shape of inputs is:(784,)
# Iteration-21496 the shape of inputs is:(784,)
# Iteration-21497 the shape of inputs is:(784,)
# Iteration-21498 the shape of inputs is:(784,)
# Iteration-21499 the shape of inputs is:(784,)
# Iteration-21500 the shape of inputs is:(784,)
# Iteration-21501 the shape of inputs is:(784,)
# Iteration-21502 the shape of inputs is:(784,)
# Iteration-21503 the shape of inputs is:(784,)
# Iteration-21504 the shape of inputs is:(784,)
# Iteration-21505 the shape of inputs is:(784,)
# Iteration-21506 the shape of inputs is:(784,)
# Iteration-21507 the shape of inputs is:(784,)
# Iteration-21508 the shape of inputs is:(784,)
# Iteration-21509 the shape of inputs is:(784,)
# Iteration-21510 the shape of inputs is:(784,)
# Iteration-21511 the shape of inputs is:(784,)
# Iteration-21512 the shape of inputs is:(784,)
# Iteration-21513 the shape of inputs is:(784,)
# Iteration-21514 the shape of inputs is:(784,)
# Iteration-21515 the shape of inputs is:(784,)
# Iteration-21516 the shape of inputs is:(784,)
# Iteration-21517 the shape of inputs is:(784,)
# Iteration-21518 the shape of inputs is:(784,)
# Iteration-21519 the shape of inputs is:(784,)
# Iteration-21520 the shape of inputs is:(784,)
# Iteration-21521 the shape of inputs is:(784,)
# Iteration-21522 the shape of inputs is:(784,)
# Iteration-21523 the shape of inputs is:(784,)
# Iteration-21524 the shape of inputs is:(784,)
# Iteration-21525 the shape of inputs is:(784,)
# Iteration-21526 the shape of inputs is:(784,)
# Iteration-21527 the shape of inputs is:(784,)
# Iteration-21528 the shape of inputs is:(784,)
# Iteration-21529 the shape of inputs is:(784,)
# Iteration-21530 the shape of inputs is:(784,)
# Iteration-21531 the shape of inputs is:(784,)
# Iteration-21532 the shape of inputs is:(784,)
# Iteration-21533 the shape of inputs is:(784,)
# Iteration-21534 the shape of inputs is:(784,)
# Iteration-21535 the shape of inputs is:(784,)
# Iteration-21536 the shape of inputs is:(784,)
# Iteration-21537 the shape of inputs is:(784,)
# Iteration-21538 the shape of inputs is:(784,)
# Iteration-21539 the shape of inputs is:(784,)
# Iteration-21540 the shape of inputs is:(784,)
# Iteration-21541 the shape of inputs is:(784,)
# Iteration-21542 the shape of inputs is:(784,)
# Iteration-21543 the shape of inputs is:(784,)
# Iteration-21544 the shape of inputs is:(784,)
# Iteration-21545 the shape of inputs is:(784,)
# Iteration-21546 the shape of inputs is:(784,)
# Iteration-21547 the shape of inputs is:(784,)
# Iteration-21548 the shape of inputs is:(784,)
# Iteration-21549 the shape of inputs is:(784,)
# Iteration-21550 the shape of inputs is:(784,)
# Iteration-21551 the shape of inputs is:(784,)
# Iteration-21552 the shape of inputs is:(784,)
# Iteration-21553 the shape of inputs is:(784,)
# Iteration-21554 the shape of inputs is:(784,)
# Iteration-21555 the shape of inputs is:(784,)
# Iteration-21556 the shape of inputs is:(784,)
# Iteration-21557 the shape of inputs is:(784,)
# Iteration-21558 the shape of inputs is:(784,)
# Iteration-21559 the shape of inputs is:(784,)
# Iteration-21560 the shape of inputs is:(784,)
# Iteration-21561 the shape of inputs is:(784,)
# Iteration-21562 the shape of inputs is:(784,)
# Iteration-21563 the shape of inputs is:(784,)
# Iteration-21564 the shape of inputs is:(784,)
# Iteration-21565 the shape of inputs is:(784,)
# Iteration-21566 the shape of inputs is:(784,)
# Iteration-21567 the shape of inputs is:(784,)
# Iteration-21568 the shape of inputs is:(784,)
# Iteration-21569 the shape of inputs is:(784,)
# Iteration-21570 the shape of inputs is:(784,)
# Iteration-21571 the shape of inputs is:(784,)
# Iteration-21572 the shape of inputs is:(784,)
# Iteration-21573 the shape of inputs is:(784,)
# Iteration-21574 the shape of inputs is:(784,)
# Iteration-21575 the shape of inputs is:(784,)
# Iteration-21576 the shape of inputs is:(784,)
# Iteration-21577 the shape of inputs is:(784,)
# Iteration-21578 the shape of inputs is:(784,)
# Iteration-21579 the shape of inputs is:(784,)
# Iteration-21580 the shape of inputs is:(784,)
# Iteration-21581 the shape of inputs is:(784,)
# Iteration-21582 the shape of inputs is:(784,)
# Iteration-21583 the shape of inputs is:(784,)
# Iteration-21584 the shape of inputs is:(784,)
# Iteration-21585 the shape of inputs is:(784,)
# Iteration-21586 the shape of inputs is:(784,)
# Iteration-21587 the shape of inputs is:(784,)
# Iteration-21588 the shape of inputs is:(784,)
# Iteration-21589 the shape of inputs is:(784,)
# Iteration-21590 the shape of inputs is:(784,)
# Iteration-21591 the shape of inputs is:(784,)
# Iteration-21592 the shape of inputs is:(784,)
# Iteration-21593 the shape of inputs is:(784,)
# Iteration-21594 the shape of inputs is:(784,)
# Iteration-21595 the shape of inputs is:(784,)
# Iteration-21596 the shape of inputs is:(784,)
# Iteration-21597 the shape of inputs is:(784,)
# Iteration-21598 the shape of inputs is:(784,)
# Iteration-21599 the shape of inputs is:(784,)
# Iteration-21600 the shape of inputs is:(784,)
# Iteration-21601 the shape of inputs is:(784,)
# Iteration-21602 the shape of inputs is:(784,)
# Iteration-21603 the shape of inputs is:(784,)
# Iteration-21604 the shape of inputs is:(784,)
# Iteration-21605 the shape of inputs is:(784,)
# Iteration-21606 the shape of inputs is:(784,)
# Iteration-21607 the shape of inputs is:(784,)
# Iteration-21608 the shape of inputs is:(784,)
# Iteration-21609 the shape of inputs is:(784,)
# Iteration-21610 the shape of inputs is:(784,)
# Iteration-21611 the shape of inputs is:(784,)
# Iteration-21612 the shape of inputs is:(784,)
# Iteration-21613 the shape of inputs is:(784,)

# %%
numpy.save('wih.npy',n.wih)
numpy.save('who.npy',n.who)

# %%
# load the mnist test data CSV file into a list
test_data_file = open("mnist_dataset/mnist_test_10000.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

# %%
# test the neural network

# scorecard for how well the network performs, initially empty
scorecard = []

# go through all the records in the test data set
for record in test_data_list:
    # split the record by the ',' commas
    all_values = record.split(',')
    # correct answer is first value
    correct_label = int(all_values[0])
    # scale and shift the inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    # query the network
    outputs = n.query(inputs)
    # the index of the highest value corresponds to the label
    label = numpy.argmax(outputs)
    # append correct or incorrect to list
    if (label == correct_label):
        # network's answer matches correct answer, add 1 to scorecard
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)

# %%
# calculate the performance score, the fraction of correct answers
scorecard_array = numpy.asarray(scorecard)
print ("accuracy = ", scorecard_array.sum() / scorecard_array.size*100,"%")
# Out:
# accuracy =  97.87 %
